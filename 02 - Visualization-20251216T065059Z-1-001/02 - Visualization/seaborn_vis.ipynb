# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Seaborn
# https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ![image.png](attachment:94257190-56bd-4561-b634-941419db3704.png)

# %% [markdown]
# #### Color Palettes
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette('mako')
# Out:
# [(0.18195582, 0.11955283, 0.23136943),
#  (0.25307401, 0.23772973, 0.48316271),
#  (0.21607792, 0.39736958, 0.61948028),
#  (0.20344718, 0.56074869, 0.65649508),
#  (0.25187832, 0.71827158, 0.67872193),
#  (0.54578602, 0.8544913, 0.69848331)]

# %%
sns.set_palette('pastel')

# %%
sns.color_palette()
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %% [markdown]
# #### Datasets

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# #### Categorical Vs Numeric

# %% [markdown]
# #### Barchart

# %%
cars = pd.read_csv("C:/Users/harik/python pratice/00 - datasets-20251216T065029Z-1-001/00 - datasets/bar_chart_data.csv")
cars.head(3)
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820

# %%
sns.catplot(cars,x='Brand',y='Cars Listings',
            kind='bar',
            height=3,
            aspect=2,
            hue ='Brand',
            palette='vlag'
           )
plt.xticks(fontsize=8)
plt.show()

# %%
sns.catplot(cars,y='Brand',x='Cars Listings',
            kind='bar',
            height=3,
            aspect=2,
            hue ='Brand'
           )
plt.xticks(fontsize=8)
plt.show()

# %% [markdown]
# #### Boxplot

# %%
sns.catplot(tips,x='day',y='total_bill',
            kind='box',
            height=3,
            aspect=2,
            hue ='day',
            palette='vlag'
           )
plt.show()

# %%
sns.catplot(tips,x='day',y='total_bill',
            kind='strip',
            height=3,
            aspect=2,
            hue ='day',
            palette='viridis'
           )
plt.show()

# %%
sns.catplot(tips,x='day',y='total_bill',
            kind='swarm',
            height=3,
            aspect=2,
            hue ='day',
            palette='viridis'
           )
plt.show()

# %%
sns.catplot(tips,x='day',y='total_bill',
            kind='swarm',
            height=3,
            aspect=2,
            hue ='time',
            palette='viridis'
           )
plt.show()

# %%
sns.catplot(tips,x='day',y='total_bill',
            kind='violin',
            height=3,
            aspect=2,
            hue ='sex',
            split=True,
            palette='vlag'
           )
plt.show()

# %% [markdown]
# #### Numeric Vs Numeric

# %% [markdown]
# #### a. Line Chart

# %%
mpg = sns.load_dataset('mpg')
mpg.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
mpg['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
sns.relplot(mpg, x='model_year', y='mpg',
            kind='line',
            height=3,
            aspect=1.5,
            #ci=False
            errorbar=('ci', False),
            palette='viridis',
            hue='origin',
            style='origin'
           )
plt.show()

# %% [markdown]
# #### Scatter Plot

# %%
hprice = pd.read_csv("C:/Users/harik/python pratice/00 - datasets-20251216T065029Z-1-001/00 - datasets/kc_house_data.csv")
hprice = hprice.head(150)

# %%
hprice.head(3)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7      1180.0              0      1955             0
# 1     0          3      7      2170.0            400      1951          1991
# 2     0          3      6       770.0              0      1933             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257           1340        5650
# 1    98125  47.7210 -122.319           1690        7639
# 2    98028  47.7379 -122.233           2720        8062

# %%
sns.relplot(hprice, x='sqft_living', y='price',
            kind='scatter',
            height=3,
            aspect=1.5,
            palette='viridis',
            #hue='origin',
            color='tomato',
            s=100,
            edgecolor='black',
            alpha =0.6
           )
plt.show()
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_19916\4243474617.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(hprice, x='sqft_living', y='price',

# %%
sns.relplot(hprice, x='sqft_living', y='price',
            kind='scatter',
            height=4,
            aspect=1.5,
            palette='mako',
            hue='bedrooms',
            #size='sqft_lot',
            s=70,
            edgecolor='black',
            alpha =0.6
           )
plt.show()

# %%
sns.relplot(tips, x='total_bill', y='tip',
            kind = 'scatter',
            height=3,
            aspect=2,
            s=70,
            hue='sex',
            palette='vlag',
            edgecolor='black'
           )
plt.title('Tip Vs Total Bill Amount')

plt.show()

# %% [markdown]
# #### Univariate Data

# %%
sns.displot(hprice, x='price',
            kind='hist',
            #kde=True,
            height=3,
            aspect=1.5,
            color='teal'
           )
plt.show()

# %%
sns.displot(hprice, x='price',
            kind='kde',
            #kde=True,
            height=3,
            aspect=1.5,
            color='teal'
           )
plt.show()

# %% [markdown]
# #### ecdf plot

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(penguins, x='flipper_length_mm',
            kind='ecdf',
            height=3,
            aspect=2,
            color='maroon'
           )
plt.show()

# %%
sns.rugplot(tips,x ='total_bill', 
            height=0.3,
            color='purple'
           )
plt.show()
