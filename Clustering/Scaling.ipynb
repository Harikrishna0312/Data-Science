# %%
import pandas as pd

# %%
udf=pd.read_csv('C://Users/harik/python pratice/Universities.csv', index_col='Univ')
udf
# Out:
#                SAT  Top10  Accept  SFRatio  Expenses  GradRate
# Univ
# Brown         1310     89      22       13     22704        94
# CalTech       1415    100      25        6     63575        81
# CMU           1260     62      59        9     25026        72
# Columbia      1310     76      24       12     31510        88
# Cornell       1280     83      33       13     21864        90
# Dartmouth     1340     89      23       10     32162        95
# Duke          1315     90      30       12     31585        95
# Georgetown    1255     74      24       12     20126        92
# Harvard       1400     91      14       11     39525        97
# JohnsHopkins  1305     75      44        7     58691        87
# MIT           1380     94      30       10     34870        91
# Northwestern  1260     85      39       11     28052        89
# NotreDame     1255     81      42       13     15122        94
# PennState     1081     38      54       18     10185        80
# ...

# %% [markdown]
# #### Standardize

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(udf)
scaled_data
# Out:
# array([[ 0.41028362,  0.6575195 , -0.88986682,  0.07026045, -0.33141256,
#          0.82030265],
#        [ 1.39925928,  1.23521235, -0.73465749, -1.68625071,  2.56038138,
#         -0.64452351],
#        [-0.06065717, -0.76045386,  1.02438157, -0.93346022, -0.16712136,
#         -1.65863393],
#        [ 0.41028362, -0.02520842, -0.78639393, -0.18066972,  0.29164871,
#          0.14422904],
#        [ 0.12771914,  0.34241431, -0.32076595,  0.07026045, -0.39084607,
#          0.36958691],
#        [ 0.69284809,  0.6575195 , -0.83813038, -0.68253005,  0.33778044,
#          0.93298158],
#        [ 0.4573777 ,  0.71003703, -0.47597528, -0.18066972,  0.29695528,
#          0.93298158],
#        [-0.10775125, -0.13024348, -0.78639393, -0.18066972, -0.51381683,
#          0.59494478],
#        [ 1.25797704,  0.76255456, -1.30375836, -0.43159988,  0.85874344,
#          1.15833946],
#        [ 0.36318954, -0.07772595,  0.24833493, -1.43532055,  2.21481798,
#          0.0315501 ],
# ...

# %%
scaled_df=pd.DataFrame(scaled_data, columns=udf.columns, index=udf.index)
scaled_df
# Out:
#                    SAT     Top10    Accept   SFRatio  Expenses  GradRate
# Univ
# Brown         0.410284  0.657519 -0.889867  0.070260 -0.331413  0.820303
# CalTech       1.399259  1.235212 -0.734657 -1.686251  2.560381 -0.644524
# CMU          -0.060657 -0.760454  1.024382 -0.933460 -0.167121 -1.658634
# Columbia      0.410284 -0.025208 -0.786394 -0.180670  0.291649  0.144229
# Cornell       0.127719  0.342414 -0.320766  0.070260 -0.390846  0.369587
# Dartmouth     0.692848  0.657519 -0.838130 -0.682530  0.337780  0.932982
# Duke          0.457378  0.710037 -0.475975 -0.180670  0.296955  0.932982
# Georgetown   -0.107751 -0.130243 -0.786394 -0.180670 -0.513817  0.594945
# Harvard       1.257977  0.762555 -1.303758 -0.431600  0.858743  1.158339
# JohnsHopkins  0.363190 -0.077726  0.248335 -1.435321  2.214818  0.031550
# MIT           1.069601  0.920107 -0.475975 -0.682530  0.529383  0.482266
# Northwestern -0.060657  0.447449 -0.010347 -0.431600  0.046981  0.256908
# ...

# %% [markdown]
# #### Normalize

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
norm = MinMaxScaler()
norm_data = norm.fit_transform(udf)
norm_data
# Out:
# array([[0.74390244, 0.84722222, 0.10526316, 0.36842105, 0.25514388,
#         0.9       ],
#        [1.        , 1.        , 0.14473684, 0.        , 1.        ,
#         0.46666667],
#        [0.62195122, 0.47222222, 0.59210526, 0.15789474, 0.29746132,
#         0.16666667],
#        [0.74390244, 0.66666667, 0.13157895, 0.31578947, 0.41562939,
#         0.7       ],
#        [0.67073171, 0.76388889, 0.25      , 0.36842105, 0.23983525,
#         0.76666667],
#        [0.81707317, 0.84722222, 0.11842105, 0.21052632, 0.4275118 ,
#         0.93333333],
#        [0.75609756, 0.86111111, 0.21052632, 0.31578947, 0.41699623,
#         0.93333333],
#        [0.6097561 , 0.63888889, 0.13157895, 0.31578947, 0.20816096,
#         0.83333333],
#        [0.96341463, 0.875     , 0.        , 0.26315789, 0.56169926,
#         1.        ],
#        [0.73170732, 0.65277778, 0.39473684, 0.05263158, 0.91099123,
#         0.66666667],
#        [0.91463415, 0.91666667, 0.21052632, 0.21052632, 0.47686392,
# ...

# %%
norm_df=pd.DataFrame(scaled_data, columns=udf.columns, index=udf.index)
norm_df
# Out:
#                    SAT     Top10    Accept   SFRatio  Expenses  GradRate
# Univ
# Brown         0.410284  0.657519 -0.889867  0.070260 -0.331413  0.820303
# CalTech       1.399259  1.235212 -0.734657 -1.686251  2.560381 -0.644524
# CMU          -0.060657 -0.760454  1.024382 -0.933460 -0.167121 -1.658634
# Columbia      0.410284 -0.025208 -0.786394 -0.180670  0.291649  0.144229
# Cornell       0.127719  0.342414 -0.320766  0.070260 -0.390846  0.369587
# Dartmouth     0.692848  0.657519 -0.838130 -0.682530  0.337780  0.932982
# Duke          0.457378  0.710037 -0.475975 -0.180670  0.296955  0.932982
# Georgetown   -0.107751 -0.130243 -0.786394 -0.180670 -0.513817  0.594945
# Harvard       1.257977  0.762555 -1.303758 -0.431600  0.858743  1.158339
# JohnsHopkins  0.363190 -0.077726  0.248335 -1.435321  2.214818  0.031550
# MIT           1.069601  0.920107 -0.475975 -0.682530  0.529383  0.482266
# Northwestern -0.060657  0.447449 -0.010347 -0.431600  0.046981  0.256908
# ...
